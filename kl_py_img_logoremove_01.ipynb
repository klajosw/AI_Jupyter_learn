# %% [markdown]
# # IMG állományok leszedése
#
# ## Használt csomagok :
# * PIL
# * os
# * datetime
# * time
#
#
# ---

# %%
import requests
import os

path = os.getcwd()
print(path)
ut=r'c:\Users\User\Documents\kl\ai_kep_kl\kl18'
dir_list = os.listdir(ut)
# megadott elérési utat: 'C:\\Users\\User\\Documents\\kl\\mintak\\jupiter\\chatgpt\\input'
# stable-diffusion-xl
for image in dir_list:
    sorszam = 0
#    print('.', image)
    
with os.scandir(ut) as i:
    for entry in i:        
        if not entry.name.startswith('.') and entry.is_dir():
            print('Nem jó', entry.name)
        if entry.name.startswith('stable-diffusion-xl') and entry.is_file() :
            image = entry.name
            filetype = image.split('.')[-1]
            print(image, filetype)
            
            
            r = requests.post('https://clipdrop-api.co/remove-background/v1',
            files={
                'image_file': (
                    image, open(f'{ut}\\{image}', 'rb'), f'image/{filetype}'
                )
            },
            headers={'x-api-key': open(f"{ut}\\YOUR_API_KEY.txt", 'r+').read().strip()}
            )
            if r.ok:
                with open(f'{ut}\\output\\{image.replace(filetype, "png")}', 'wb') as f:
                    f.write(r.content)
                print('+', image)
            else:
                r.raise_for_status()
                print('ERROR:', image)
# Out:
# C:\Users\User\Documents\kl\mintak\jupiter\chatgpt
# Nem jó kesz
# Nem jó output
# stable-diffusion-xl (1).jpeg jpeg
# + stable-diffusion-xl (1).jpeg
# stable-diffusion-xl (10).jpeg jpeg
# + stable-diffusion-xl (10).jpeg
# stable-diffusion-xl (100).jpeg jpeg
# + stable-diffusion-xl (100).jpeg
# stable-diffusion-xl (11).jpeg jpeg
# + stable-diffusion-xl (11).jpeg
# stable-diffusion-xl (12).jpeg jpeg
# + stable-diffusion-xl (12).jpeg
# stable-diffusion-xl (13).jpeg jpeg
# + stable-diffusion-xl (13).jpeg
# stable-diffusion-xl (14).jpeg jpeg
# + stable-diffusion-xl (14).jpeg
# stable-diffusion-xl (15).jpeg jpeg
# + stable-diffusion-xl (15).jpeg
# stable-diffusion-xl (16).jpeg jpeg
# + stable-diffusion-xl (16).jpeg
# stable-diffusion-xl (17).jpeg jpeg
# + stable-diffusion-xl (17).jpeg
# stable-diffusion-xl (18).jpeg jpeg
# + stable-diffusion-xl (18).jpeg
# stable-diffusion-xl (19).jpeg jpeg
# + stable-diffusion-xl (19).jpeg
# stable-diffusion-xl (2).jpeg jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d13e9e2f8e7e> in <module>
#      22
#      23
# ---> 24             r = requests.post('https://clipdrop-api.co/remove-background/v1',
#      25             files={
#      26                 'image_file': (
#
# ~\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
import os

path = os.getcwd()
dir_list = os.listdir(f'{path}\\input')

for image in dir_list:
    print('.', image)
    
    if os.path.isfile(f'{path}\\output\\{image}'):
        print(f'ERROR: {image} File already exists.')
    else:
        filetype = image.split('.')[-1]

        r = requests.post('https://clipdrop-api.co/remove-background/v1',
            files={
                'image_file': (
                    image, open(f'{path}\\input\\{image}', 'rb'), f'image/{filetype}'
                )
            },
            headers={'x-api-key': open(f"{path}\\YOUR_API_KEY.txt", 'r+').read().strip()}
        )
        if r.ok:
            with open(f'{path}\\output\\{image.replace(filetype, "png")}', 'wb') as f:
                f.write(r.content)
            print('+', image)
        else:
            r.raise_for_status()
            print('ERROR:', image)

# %%
import os
import datetime
import time
from PIL import Image, ExifTags

kezdo = time.time()      ## futás kezdő idő

## indítási könyvtár megadása
dir_munka = r'c:\Users\User\Documents\kl\ai_kep_kl' +'\\'
dir_tmp   = 'kl21'
# c:\Users\User\Documents\kl\ai_kep_kl\ai_kepek\kl4\

ut = dir_munka + dir_tmp    ## könyvtár összerakása
os.chdir(ut)                ## Munkakönyvtár beállítása
# print(os.getcwd())        ## Munkakönyvtár helyének kiíratása

img2 = Image.open(r"c:\Users\User\Documents\kl\kl_mie.jpg"); ## logo képfile helye

# ha nincs kesz könyvtár, akkor létrehozzás
dir_kesz = os.path.join(ut, 'kesz')
if not os.path.exists(dir_kesz):
    os.makedirs(dir_kesz)
#    os.mkdir(dir_kesz)


## dátum átalakítás
def ts_to_dt(ts):
    return datetime.datetime.fromtimestamp(ts)

## képek összefüzése
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width , im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (0,im1.height -61))
    return dst


## fő száll
sorszam = 9000
with os.scandir(ut) as i:
    for entry in i:        
        if entry.is_file():
            sorszam = sorszam + 1
            img1 = Image.open(ut + '\\' + entry.name)
#            print(entry.name)
            exif = img1.getexif()
            exif[37510] = "------>  This is an image I generated"
            exif[33432] = "http://mierdekel.hu || mierdekel@gmail.com"
            exif[315] = "klajosw@gmail.com"
            exif[270] = "This is an image I generated"
            img3 = get_concat_h(img1, img2)
            img3.save(ut + '\\kesz\\' + 'kl_mie_'+ dir_tmp + '_' +  str(sorszam) + '.jpg', exif=exif)
       
print('-----------------------')
print (time.time() - kezdo, " másodperc alatt futott le.")
# Out:
# -----------------------
# 6.4724719524383545  másodperc alatt futott le.

# %%
from PIL import Image
im = Image.open(r"c:\Users\kecskemetil\Documents\sj\ai_gen_kepek\bing\ai_ember\kesz\kl_mie_kesz1.jpg")
exif = im.getexif()
exif[37510] = "------>  This is an image I generated"
exif[33432] = "http://mierdekel.hu || mierdekel@gmail.com"
exif[315] = "klajosw@gmail.com"
exif[270] = "This is an image I generated"
im.save("out.jpg", exif=exif)
kl_inf01 = '''
tag_name_to_id[270] = 'ImageDescription'
tag_name_to_id[306] = 'DateTime'
tag_name_to_id[256] = 'ImageWidth'
tag_name_to_id[257] = 'ImageLength'
tag_name_to_id[258] = 'BitsPerSample'
tag_name_to_id[40962] = 'PixelXDimension'
tag_name_to_id[40963] = 'PixelYDimension'
tag_name_to_id[305] = 'Software'
tag_name_to_id[37510] = 'UserComment'
tag_name_to_id[40091] = 'XPTitle'
tag_name_to_id[40092] = 'XPComment'
tag_name_to_id[40093] = 'XPAuthor'
tag_name_to_id[40094] = 'XPKeywords'
tag_name_to_id[40095] = 'XPSubject'
tag_name_to_id[40961] = 'ColorSpace' # Bit depth
tag_name_to_id[315] = 'Artist'
tag_name_to_id[33432] = 'Copyright'
'''
